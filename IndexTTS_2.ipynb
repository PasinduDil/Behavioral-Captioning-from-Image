# %% [markdown]
# ### 🏷️ **Credits: [index-tts](https://github.com/index-tts/index-tts)**
#
#
#
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install IndexTTS-2    [🕒 Wait for 2 minutes]
# %cd /content
# !rm -rf /content/index-tts
# !git lfs install
# !git clone https://github.com/index-tts/index-tts.git
# !git clone https://github.com/NeuralFalconYT/index-tts.git
# %cd index-tts
# !git lfs pull
# !wget https://raw.githubusercontent.com/NeuralFalconYT/Useful-Function/refs/heads/main/hf_downloader.py
# !pip install uv --quiet
# !uv sync --all-extras
from IPython.display import clear_output
clear_output()

# %%
#@title Download IndexTTS-2 Model [🕒 Wait for 40 seconds]
# %cd /content/index-tts
from hf_downloader import download_model
from IPython.display import clear_output
clear_output()
def add_share(file_path="/content/index-tts/webui.py"):
    with open(file_path, "r") as f:
        lines = f.readlines()

    for i, line in enumerate(lines):
        if "demo.launch" in line:
            lines[i] = "    demo.launch(share=True, debug=True)\n"

    with open(file_path, "w") as f:
        f.writelines(lines)

    print(f"✅ Updated {file_path} with share=True, debug=True")



model_path = download_model(
    "IndexTeam/IndexTTS-2",
    download_folder="./checkpoints",
    redownload=False
)
clear_output()
print("✅ Model saved at:", model_path)
add_share()
# Out:
# ✅ Model saved at: /content/index-tts/checkpoints/IndexTTS-2
# ✅ Updated /content/index-tts/webui.py with share=True, debug=True

# %%
#@title Run IndexTTS-2  [🕒 Wait for 3 minutes]
# %cd /content/index-tts
# !uv run webui.py --model_dir "/content/index-tts/checkpoints/IndexTTS-2"
# Out:
# /content/index-tts
# >> GPT weights restored from: /content/index-tts/checkpoints/IndexTTS-2/gpt.pth
# GPT2InferenceModel has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# preprocessor_config.json: 100% 275/275 [00:00<00:00, 1.57MB/s]
# config.json: 1.87kB [00:00, 6.22MB/s]
# model.safetensors: 100% 2.32G/2.32G [00:29<00:00, 79.2MB/s]
# semantic_codec/model.safetensors: 100% 177M/177M [00:02<00:00, 72.9MB/s]
# >> semantic_codec weights restored from: /root/.cache/huggingface/hub/models--amphion--MaskGCT/snapshots/265c6cef07625665d0c28d2faafb1415562379dc/semantic_codec/model.safetensors
# cfm loaded
# length_regulator loaded
# gpt_layer loaded
# >> s2mel weights restored from: /content/index-tts/checkpoints/IndexTTS-2/s2mel.pth
# campplus_cn_common.bin: 100% 28.0M/28.0M [00:00<00:00, 73.1MB/s]
# >> campplus_model weights restored from: /root/.cache/huggingface/hub/models--funasr--campplus/snapshots/fb71fe990cbf6031ae6987a2d76fe64f94377b7e/campplus_cn_common.bin
# config.json: 1.41kB [00:00, 7.03MB/s]
# Loading weights from nvidia/bigvgan_v2_22khz_80band_256x
# bigvgan_generator.pt: 100% 449M/449M [00:05<00:00, 88.2MB/s]
# Removing weight norm...
# >> bigvgan weights restored from: nvidia/bigvgan_v2_22khz_80band_256x
# 2026-03-22 07:14:10,752 WETEXT INFO building fst for zh_normalizer ...
# 2026-03-22 07:14:50,129 WETEXT INFO done
# 2026-03-22 07:14:50,129 WETEXT INFO fst path: /content/index-tts/indextts/utils/tagger_cache/zh_tn_tagger.fst
# 2026-03-22 07:14:50,129 WETEXT INFO           /content/index-tts/indextts/utils/tagger_cache/zh_tn_verbalizer.fst
# 2026-03-22 07:14:50,135 WETEXT INFO found existing fst: /content/index-tts/.venv/lib/python3.10/site-packages/tn/en_tn_tagger.fst
# 2026-03-22 07:14:50,135 WETEXT INFO                     /content/index-tts/.venv/lib/python3.10/site-packages/tn/en_tn_verbalizer.fst
# 2026-03-22 07:14:50,135 WETEXT INFO skip building fst for en_normalizer ...
# >> TextNormalizer loaded
# >> bpe model loaded from: /content/index-tts/checkpoints/IndexTTS-2/bpe.model
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://f705755f6db0175490.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Emo control mode:0,vec:None
# >> start inference...
# Use the specified emotion vector
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.53.0. You should pass an instance of `Cache` instead, e.g. `past_key_values=DynamicCache.from_legacy_cache(past_key_values)`.
# 100% 25/25 [00:26<00:00,  1.08s/it]
# torch.Size([1, 398848])
# Use the specified emotion vector
# 100% 25/25 [00:15<00:00,  1.61it/s]
# torch.Size([1, 425984])
# Use the specified emotion vector
# 100% 25/25 [00:21<00:00,  1.17it/s]
# torch.Size([1, 581888])
# >> gpt_gen_time: 101.49 seconds
# >> gpt_forward_time: 0.06 seconds
# >> s2mel_time: 64.92 seconds
# >> bigvgan_time: 7.31 seconds
# >> Total inference time: 183.06 seconds
# >> Generated audio length: 64.20 seconds
# >> RTF: 2.8515
# >> wav file saved to: outputs/spk_1774163807.wav
# Traceback (most recent call last):
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/queueing.py", line 667, in process_events
#     response = await route_utils.call_process_api(
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/route_utils.py", line 349, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/blocks.py", line 2270, in process_api
#     inputs = await self.preprocess_data(
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/blocks.py", line 1912, in preprocess_data
#     inputs_cached = await processing_utils.async_move_files_to_cache(
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/processing_utils.py", line 676, in async_move_files_to_cache
#     return await client_utils.async_traverse(
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio_client/utils.py", line 1197, in async_traverse
#     return await func(json_obj)
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/processing_utils.py", line 647, in _move_to_cache
#     _check_allowed(payload.path, check_in_upload_folder)
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/processing_utils.py", line 592, in _check_allowed
#     raise InvalidPathError(msg)
# gradio.exceptions.InvalidPathError: Cannot move /content/index-tts/examples/voice_02.wav to the gradio cache dir because it was not uploaded by a user.
# Traceback (most recent call last):
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/queueing.py", line 667, in process_events
#     response = await route_utils.call_process_api(
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/route_utils.py", line 349, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/blocks.py", line 2270, in process_api
#     inputs = await self.preprocess_data(
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/blocks.py", line 1912, in preprocess_data
#     inputs_cached = await processing_utils.async_move_files_to_cache(
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/processing_utils.py", line 676, in async_move_files_to_cache
#     return await client_utils.async_traverse(
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio_client/utils.py", line 1197, in async_traverse
#     return await func(json_obj)
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/processing_utils.py", line 647, in _move_to_cache
#     _check_allowed(payload.path, check_in_upload_folder)
#   File "/content/index-tts/.venv/lib/python3.10/site-packages/gradio/processing_utils.py", line 592, in _check_allowed
#     raise InvalidPathError(msg)
# gradio.exceptions.InvalidPathError: Cannot move /content/index-tts/examples/voice_02.wav to the gradio cache dir because it was not uploaded by a user.
# Emo control mode:2,vec:[0, 0, 0, 0, 0, 0, 0.5, 0]
# >> start inference...
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.12it/s]
# torch.Size([1, 241152])
# >> gpt_gen_time: 14.62 seconds
# >> gpt_forward_time: 0.03 seconds
# >> s2mel_time: 22.56 seconds
# >> bigvgan_time: 1.60 seconds
# >> Total inference time: 39.37 seconds
# >> Generated audio length: 10.94 seconds
# >> RTF: 3.6000
# >> wav file saved to: outputs/spk_1774164230.wav
# Emo control mode:2,vec:[0, 0, 0, 0, 0, 0, 0.3, 0]
# >> start inference...
# Use the specified emotion vector
# 100% 25/25 [00:25<00:00,  1.02s/it]
# torch.Size([1, 187392])
# >> gpt_gen_time: 10.95 seconds
# >> gpt_forward_time: 0.02 seconds
# >> s2mel_time: 25.55 seconds
# >> bigvgan_time: 1.79 seconds
# >> Total inference time: 44.98 seconds
# >> Generated audio length: 8.50 seconds
# >> RTF: 5.2932
# >> wav file saved to: outputs/spk_1774164385.wav
# Emo control mode:2,vec:[0, 0, 0, 0, 0, 0, 0.05, 0]
# >> start inference...
# Use the specified emotion vector
# 100% 25/25 [00:26<00:00,  1.06s/it]
# torch.Size([1, 201984])
# >> gpt_gen_time: 11.97 seconds
# >> gpt_forward_time: 0.02 seconds
# >> s2mel_time: 26.60 seconds
# >> bigvgan_time: 1.90 seconds
# >> Total inference time: 40.88 seconds
# >> Generated audio length: 9.16 seconds
# >> RTF: 4.4629
# >> wav file saved to: outputs/spk_1774164499.wav
# Emo control mode:0,vec:None
# >> start inference...
# Use the specified emotion vector
# 100% 25/25 [00:26<00:00,  1.07s/it]
# torch.Size([1, 199680])
# >> gpt_gen_time: 12.21 seconds
# >> gpt_forward_time: 0.02 seconds
# >> s2mel_time: 26.87 seconds
# >> bigvgan_time: 1.95 seconds
# >> Total inference time: 41.45 seconds
# >> Generated audio length: 9.06 seconds
# >> RTF: 4.5768
# >> wav file saved to: outputs/spk_1774164608.wav
